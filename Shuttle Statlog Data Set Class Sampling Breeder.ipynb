# %% [markdown]
# # Shuttle Statlog Data Set Classifier - Breeder Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import numpy as np
import copy
# %matplotlib inline

# %%
import GeneticProgram as gp
from Statlog import load_statlog
from SamplingPolicies import *

# %% [markdown]
# ### Import Data Set

# %%
# Data set already scaled
train_X, train_y, test_X, test_y, num_inputs, num_classes = load_statlog()

# Create scaler based only on the training set
scaler = MinMaxScaler()
scaler.fit(train_X)

# Scale datasets
train_X = scaler.transform(train_X)
test_X  = scaler.transform(test_X)

# %%
def breederDisplayCallback(string):
    clear_output(wait=True)
    display(string)

# %%
template_program = gp.Program(
     max_initial_instructions = 128,
     num_registers            = 16,
     num_inputs               = num_inputs,
     mutation_rate            = 0.1,
     max_num_instructions     = 1024,
     num_classes              = num_classes
)

# %%
results = []

# %%
res = gp.breederSelection(p_size                = 100,
                          p_gap                 =  70,
                          tau                   = 200,
                          template_program      = template_program,
                          sampling_policy_class = UniformSamplingPolicy,
                          max_num_generations   = 200,
                          X                     = train_X,
                          y                     = train_y,
                          display_fun           = breederDisplayCallback)
results.append(copy.deepcopy(res))
# Out:
# 'Round 199 - Fitness 197.0'

# %%
plt.plot(res[2]['fitness_union'])

# %%
plt.plot(res[2]['fitness'])

# %%
plt.plot(res[2]['best_fitness'])

# %%
res[0].accuracy(train_X, train_y)
# Out:
# 0.9426666666666667

# %%
res[0].accuracy(test_X, test_y)
# Out:
# 0.9404137931034483

# %%
res[0].detectionRate(train_X, train_y)
# Out:
# 0.393772998556483

# %%
res[0].detectionRate(test_X, test_y)
# Out:
# 0.3933788029119653

# %%
res = gp.breederSelection(p_size                = 100,
                          p_gap                 =  70,
                          tau                   = 200,
                          template_program      = template_program,
                          sampling_policy_class = ClassUniformSamplingPolicy,
                          max_num_generations   = 200,
                          X                     = train_X,
                          y                     = train_y,
                          display_fun           = breederDisplayCallback)
results.append(copy.deepcopy(res))
# Out:
# 'Round 199 - Fitness 108.0'

# %%
plt.plot(res[2]['fitness_union'])

# %%
plt.plot(res[2]['fitness'])

# %%
plt.plot(res[2]['best_fitness'])

# %%
res[0].accuracy(train_X, train_y)
# Out:
# 0.05577011494252874

# %%
res[0].accuracy(test_X, test_y)
# Out:
# 0.055310344827586205

# %%
res[0].detectionRate(train_X, train_y)
# Out:
# 0.5160587182556263

# %%
res[0].detectionRate(test_X, test_y)
# Out:
# 0.5560249392140616

# %%
res = gp.fitnessSharingBreederSelection(p_size                = 100,
                                        p_gap                 =  70,
                                        tau                   = 200,
                                        template_program      = template_program,
                                        sampling_policy_class = UniformSamplingPolicy,
                                        max_num_generations   = 200,
                                        X                     = train_X,
                                        y                     = train_y,
                                        display_fun           = breederDisplayCallback)
results.append(copy.deepcopy(res))
# Out:
# 'Round 199 - Fitness 13.0'

# %%
plt.plot(res[2]['fitness_union'])

# %%
plt.plot(res[2]['fitness'])

# %%
plt.plot(res[2]['best_fitness'])

# %%
res[0].accuracy(train_X, train_y)
# Out:
# 0.11995402298850574

# %%
res[0].accuracy(test_X, test_y)
# Out:
# 0.11503448275862069

# %%
res[0].detectionRate(train_X, train_y)
# Out:
# 0.13425494679199482

# %%
res[0].detectionRate(test_X, test_y)
# Out:
# 0.21751740139211137

# %%
res = gp.fitnessSharingBreederSelection(p_size                = 100,
                                        p_gap                 =  70,
                                        tau                   = 200,
                                        template_program      = template_program,
                                        sampling_policy_class = ClassUniformSamplingPolicy,
                                        max_num_generations   = 200,
                                        X                     = train_X,
                                        y                     = train_y,
                                        display_fun           = breederDisplayCallback)
results.append(copy.deepcopy(res))
# Out:
# 'Round 199 - Fitness 6.563528138528138'

# %%
plt.plot(res[2]['fitness_union'])

# %%
plt.plot(res[2]['fitness'])

# %%
plt.plot(res[2]['best_fitness'])

# %%
res[0].accuracy(train_X, train_y)
# Out:
# 0.7282988505747127

# %%
res[0].accuracy(test_X, test_y)
# Out:
# 0.733448275862069

# %%
res[0].detectionRate(train_X, train_y)
# Out:
# 0.26257413028148363

# %%
res[0].detectionRate(test_X, test_y)
# Out:
# 0.2751972717994673
